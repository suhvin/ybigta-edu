# %% [markdown]
# <a href="https://colab.research.google.com/github/suhvin/ybigta-edu/blob/master/AWS_0815_%EC%84%9C%EA%B8%B0%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##EC2 만들기

# %% [markdown]
# ![스크린샷 2022-08-15 오후 6.58.44.png](data:image/png;base64,...)

# %% [markdown]
# ##aws.py 만들기

# %% [markdown]
# ![스크린샷 2022-08-15 오후 6.59.24.png](data:image/png;base64,...)

# %% [markdown]
# ##파일 서버와 주고 받기
#
# - local >>> 서버 : aws.py
# - 서버에서 aws.py 실행
# - 서버 >>> local : hi.txt

# %% [markdown]
# ![스크린샷 2022-08-15 오후 6.59.54.png](data:image/png;base64,...)
